# %% [markdown]
# ### ANS 1
#
# Exceotion is and superclass whidh all the classes of exception.We use Exception in custom exception classes in the argumnet to inherit the properites of excetion superclass.

# %% [markdown]
# ### ANS 5
# import error= is excuted when we want to import a module buth there is no such kind of module exsist in the library.
# modulenotfound error occours when module is present but it is not loading beacuse of some error.

# %%
try:
    import aman
except ModuleNotFoundError as e:
    print(e)
# Out:
# No module named 'aman'

# %%
try:
    import aman
except ImportError as e:
    print(e)
# Out:
# No module named 'aman'

# %% [markdown]
# ### ANS 3
# zerodivison,floating point error,overflow error are error defined in arthimetic error

# %%
try:
    1/0
except ZeroDivisionError as e:
    print(e)
# Out:
# division by zero

# %%
j=5.0
try:
    for i in range(1,100000):
        c=j**i
        print(c)
except OverflowError as e:
    print('oveflow error has happend')
# Out:
# 5.0
# 25.0
# 125.0
# 625.0
# 3125.0
# 15625.0
# 78125.0
# 390625.0
# 1953125.0
# 9765625.0
# 48828125.0
# 244140625.0
# 1220703125.0
# 6103515625.0
# 30517578125.0
# 152587890625.0
# 762939453125.0
# 3814697265625.0
# 19073486328125.0
# 95367431640625.0
# 476837158203125.0
# 2384185791015625.0
# 1.1920928955078124e+16
# 5.960464477539062e+16
# 2.9802322387695315e+17
# 1.4901161193847657e+18
# 7.450580596923828e+18
# 3.725290298461914e+19
# 1.862645149230957e+20
# 9.313225746154785e+20
# 4.6566128730773924e+21
# 2.3283064365386964e+22
# 1.164153218269348e+23
# 5.8207660913467404e+23
# 2.9103830456733703e+24
# 1.4551915228366852e+25
# 7.2759576141834256e+25
# 3.637978807091713e+26
# 1.8189894035458564e+27
# 9.094947017729283e+27
# 4.547473508864641e+28
# 2.2737367544323207e+29
# 1.1368683772161603e+30
# 5.684341886080802e+30
# 2.8421709430404005e+31
# 1.4210854715202004e+32
# 7.105427357601002e+32
# 3.552713678800501e+33
# 1.7763568394002504e+34
# 8.881784197001253e+34
# ...

# %% [markdown]
# ### ans 4
# look up error are used when key and index is not valid

# %%
try:
    d={1:[1,23,4],'key 4':'not a valid key'}
    print(d['key3'])
except KeyError as e:
    print('key is not valid')
# Out:
# key is not valid

# %%
try:
    l=[923,4,5,]
    print(l[7])
except IndexError as e:
    print(e)
# Out:
# list index out of range

# %% [markdown]
# ### ANS 6
# 1) always print proper errror
# 2) try loggging your error
# 3) avoid using multiple exception
# 4) document all the error ?

# %% [markdown]
# ### ANS 2

# %% [raw]
# BaseException
#  +-- SystemExit
#  +-- KeyboardInterrupt
#  +-- GeneratorExit
#  +-- Exception
#       +-- StopIteration
#       +-- StandardError
#       |    +-- BufferError
#       |    +-- ArithmeticError
#       |    |    +-- FloatingPointError
#       |    |    +-- OverflowError
#       |    |    +-- ZeroDivisionError
#       |    +-- AssertionError
#       |    +-- AttributeError
#       |    +-- EnvironmentError
#       |    |    +-- IOError
#       |    |    +-- OSError
#       |    |         +-- WindowsError (Windows)
#       |    |         +-- VMSError (VMS)
#       |    +-- EOFError
#       |    +-- ImportError
#       |    +-- LookupError
#       |    |    +-- IndexError
#       |    |    +-- KeyError
#       |    +-- MemoryError
#       |    +-- NameError
#       |    |    +-- UnboundLocalError
#       |    +-- ReferenceError
#       |    +-- RuntimeError
#       |    |    +-- NotImplementedError
#       |    +-- SyntaxError
#       |    |    +-- IndentationError
#       |    |         +-- TabError
#       |    +-- SystemError
#       |    +-- TypeError
#       |    +-- ValueError
#       |         +-- UnicodeError
#       |              +-- UnicodeDecodeError
#       |              +-- UnicodeEncodeError
#       |              +-- UnicodeTranslateError
#       +-- Warning
#            +-- DeprecationWarning
#            +-- PendingDeprecationWarning
#            +-- RuntimeWarning
#            +-- SyntaxWarning
#            +-- UserWarning
#            +-- FutureWarning
# 	   +-- ImportWarning
# 	   +-- UnicodeWarning
# 	   +-- BytesWarning
