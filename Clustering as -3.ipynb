# %% [markdown]
# ### ANS 1
# basic concept of clustring is it groups the similar points and make one  cluster according to the number of cluster given by the user it makes that number of clusters.
# ***
# applications:
# 1) it is used to target the specific audience
# 2) it can used in hospitals.
# 3) it can used in shopping complex.

# %% [markdown]
# ### ANS 2
# DBSCAN is a type of clustring algorithim. it works on the basis of radius and minipoints if in one particular radius covers poinnts less then  minipoints it can be target as border if greater than it can be target as red and if no point it can termed as blue.
# 1) Its algorithim is different from other
# 2) it is robust and it has different appraoch.
# 3) it can be used for non linear raltionship.

# %% [markdown]
# ### ANS 3
# we can determine the optimal value of epsilon and minimum points parameter by using girdsearhcv or Randomsearchcv.

# %% [markdown]
# ### ANS 4
# In DBSCAN if no minipoints comes under ebsilon radius it then these are termed as blue.

# %% [markdown]
# ### ANS 5
# 1) DBSCAN can be used for linear and non linear relationship but Kmeans can be used for only linear relationship.
# 2) In DBSCAN we do not define number of centriods but in Kmeans we define number of centriods.
# 3) In DBSCAN  we define radius but in k means we don't define radius.

# %% [markdown]
# ### ANS 6
# yes dbscan can be used for high dimesional feature because it consider points under some radius which can be used for higher number of dimensions.
# ***
# 1) definning epsilon radious can be difficult.
# 2) deffining minpoints can also be challenging.
# 3) it can be very complex.

# %% [markdown]
# ### ANS 7
# DBSCAN clustering can identify clusters of varying densities. high density area will from cluster with many points,while lower-density area will from smaller cluster.

# %% [markdown]
# ### ANS 8
# we use silhoitee score to check the performance of dbscan clustring or we can visualize the graph to check the performance.

# %% [markdown]
# ### ANS 9
# yes it can be used for semi supervised learning as it also does not require labeled data.

# %% [markdown]
# ### ANS 10
# DBSCAN does not assign noise and outlier in the cluster as outlier epsilon radius do not have any points which help them not assigning in the cluster.

# %% [markdown]
# ### ANS 11

# %%
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
X,y=make_moons(n_samples=250,noise=0.10)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_scaled=scaler.fit_transform(X)

# %%
dbcan=DBSCAN(eps=0.3)

# %%
dbcan.fit(X_scaled)
# Out:
# DBSCAN(eps=0.3)

# %%
plt.scatter(X[:,0],X[:,1],c=dbcan.labels_)
