# %% [markdown]
# ### ANS 1
# 1) fixed acid and connic acid both are strongly correlated with each other(positive correleation).
# 2) ph and fixed aciditu have the most negative correleation

# %% [markdown]
# ### ANS 2
# we can find the missing value by using isnull() function. We can use varaious technique to handle missing value for example:
# 1) mean:
# we can use mean technique to replace missing value with mean it is used for numerical data we do not have any outliers.
# 2) mode:
# we can use mode in case of categorical data
# 3) median:
# meadian technique is used when our data have outliers.

# %% [markdown]
# ### ANS 5

# %%
import pandas as pd 
df=pd.read_csv('wineQualityReds.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            1599 non-null   int64
#  1   fixed.acidity         1599 non-null   float64
#  2   volatile.acidity      1599 non-null   float64
#  3   citric.acid           1599 non-null   float64
#  4   residual.sugar        1599 non-null   float64
#  5   chlorides             1599 non-null   float64
#  6   free.sulfur.dioxide   1599 non-null   float64
#  7   total.sulfur.dioxide  1599 non-null   float64
#  8   density               1599 non-null   float64
#  9   pH                    1599 non-null   float64
#  10  sulphates             1599 non-null   float64
#  11  alcohol               1599 non-null   float64
#  12  quality               1599 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 162.5 KB

# %%
df.drop('Unnamed: 0',inplace=True,axis=1)

# %%
df.head(1)
# Out:
#    fixed.acidity  volatile.acidity  citric.acid  ...  sulphates  alcohol  quality
# 0            7.4               0.7          0.0  ...       0.56      9.4        5
#
# [1 rows x 12 columns]

# %%
df.describe()
# Out:
#        fixed.acidity  volatile.acidity  ...      alcohol      quality
# count    1599.000000       1599.000000  ...  1599.000000  1599.000000
# mean        8.319637          0.527821  ...    10.422983     5.636023
# std         1.741096          0.179060  ...     1.065668     0.807569
# min         4.600000          0.120000  ...     8.400000     3.000000
# 25%         7.100000          0.390000  ...     9.500000     5.000000
# 50%         7.900000          0.520000  ...    10.200000     6.000000
# 75%         9.200000          0.640000  ...    11.100000     6.000000
# max        15.900000          1.580000  ...    14.900000     8.000000
#
# [8 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# fixed.acidity           0
# volatile.acidity        0
# citric.acid             0
# residual.sugar          0
# chlorides               0
# free.sulfur.dioxide     0
# total.sulfur.dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 240

# %%
df[df.duplicated()]
# Out:
#       fixed.acidity  volatile.acidity  citric.acid  ...  sulphates  alcohol  quality
# 4               7.4             0.700         0.00  ...       0.56      9.4        5
# 11              7.5             0.500         0.36  ...       0.80     10.5        5
# 27              7.9             0.430         0.21  ...       0.91      9.5        5
# 40              7.3             0.450         0.36  ...       0.83     10.5        5
# 65              7.2             0.725         0.05  ...       0.39     10.9        5
# ...             ...               ...          ...  ...        ...      ...      ...
# 1563            7.2             0.695         0.13  ...       0.54     10.1        5
# 1564            7.2             0.695         0.13  ...       0.54     10.1        5
# 1567            7.2             0.695         0.13  ...       0.54     10.1        5
# 1581            6.2             0.560         0.09  ...       0.60     11.3        5
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#    fixed.acidity  volatile.acidity  citric.acid  ...  sulphates  alcohol  quality
# 0            7.4              0.70         0.00  ...       0.56      9.4        5
# 1            7.8              0.88         0.00  ...       0.68      9.8        5
# 2            7.8              0.76         0.04  ...       0.65      9.8        5
# 3           11.2              0.28         0.56  ...       0.58      9.8        6
# 5            7.4              0.66         0.00  ...       0.56      9.4        5
#
# [5 rows x 12 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1359 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed.acidity         1359 non-null   float64
#  1   volatile.acidity      1359 non-null   float64
#  2   citric.acid           1359 non-null   float64
#  3   residual.sugar        1359 non-null   float64
#  4   chlorides             1359 non-null   float64
#  5   free.sulfur.dioxide   1359 non-null   float64
#  6   total.sulfur.dioxide  1359 non-null   float64
#  7   density               1359 non-null   float64
#  8   pH                    1359 non-null   float64
#  9   sulphates             1359 non-null   float64
#  10  alcohol               1359 non-null   float64
#  11  quality               1359 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 138.0 KB

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(feature)):
    plt.subplot(5, 3, i+1)
    sns.kdeplot(x=df[feature[i]],shade=True, color='r')
    plt.xlabel(feature[i])
    plt.tight_layout()

# %%
feature=[feature for feature in df.columns]

# %% [markdown]
# ### ANS 6

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
scaler=StandardScaler()
scaled=scaler.fit_transform(df)

# %%
pca=PCA()
principle_components=pca.fit_transform(scaled)

# %%
explained_varaince_ratio=pca.explained_variance_ratio_

# %%
cumulative_varaince=np.cumsum(explained_varaince_ratio)

# %% [markdown]
# num_component=np.argmax(cumulative_varaince>=0.90)

# %%
print(num_component)
# Out:
# 7

# %%
print(explained_varaince_ratio)
# Out:
# [0.26100983 0.1867395  0.13946427 0.10435684 0.08068005 0.0538768
#  0.05147181 0.04149976 0.0333964  0.02761532 0.01498122 0.00490819]

# %%
print(cumulative_varaince)
# Out:
# [0.26100983 0.44774933 0.5872136  0.69157044 0.77225049 0.82612729
#  0.87759911 0.91909887 0.95249527 0.98011059 0.99509181 1.        ]

# %% [markdown]
# ### ANS 4
# feature engineering is used to select the:
# 1) feature selection
# 2) feaure scalling
# 3) PCA
# We can use feature engineering  in the context of student performanace by using pca to reduce the feature. or can use correlation to pick up the most important feature relevant to the data we want to get.

# %% [markdown]
# ### ANS 3
# with the statist we can analyzise for example
# 1) if the curve is  right skewed or left skewed then we can make assumption on the basis of properities of lef and right skewed.
# 2) we can uses statics to find the mean,mode,median in order to find the average.
# 3) we can make graph comparison to some other important feature to find the relation
# 4) we can use corr to find the negative and positive effect on something
# 5) we can make certain assumption about the graph using statics formula or imputation.
# ***
# key feature:
# 1) Standard Lunch help students perform well in exams
# 2) Standard lunch helps perform well in exams be it a male of female
# 3) In general parent's education don't help student perform well in exam.
# 4)  parent's whose education is of associate's degree or master's degree their male child tend to perform well in exam
# 5)  there is no effect of parent's education on female students
